# %% [markdown]
# ## Sandbox

# %%
import sys

import requests
from bs4 import BeautifulSoup

import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib

# %%
from requests_html import AsyncHTMLSession

async def fetch_url():
    asession = AsyncHTMLSession()
    API = 'https://www.migros.ch/fr/category/fruits-legumes/fruits'
    
    r = await asession.get(API)
    await r.html.arender()
    
    resp = r.html.html
    return resp

import nest_asyncio
nest_asyncio.apply()

import asyncio

resp = asyncio.run(fetch_url())
print(resp)
# Out:
# <!DOCTYPE html><html class="no-js" data-critters-container=""><head itemscope="" itemtype="http://schema.org/WebSite">
# 		<script>
# 			if (typeof window !== 'undefined') {
# 				window.prerenderReady = false;
# 			}
# 		</script>
# 		<meta charset="utf-8">
# 		<title>Migros</title>
# 		<meta name="description" content="Commandez en ligne et gagnez du temps - nous vous livrons vos courses à votre porte. 12'500 produits Migros à prix Migros et articles de marque">
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">
# 		<meta name="apple-mobile-web-app-capable" content="yes">
# 		<meta name="apple-mobile-web-app-title" itemprop="name" content="migros.ch">
# 		<meta name="apple-mobile-web-app-status-bar-style" content="default">
# 		<!-- microdata -->
# 		<meta itemprop="url" content="https://www.migros.ch">
# 		<meta itemprop="description" content="Migros">
# 		<meta itemprop="image" content="https://www.migros.ch/assets/mgb-favicons/icon-512x512.png">
# 		<!-- seo -->
# 		<meta name="keywords">
# 		<meta name="title">
# 		<!-- social:og-->
# 		<meta property="og:url">
# 		<meta property="og:type" content="website">
# 		<meta property="og:site_name" content="Migros">
# 		<meta property="og:title">
# 		<meta property="og:description">
# 		<meta property="og:locale">
# 		<meta property="og:image" content="https://www.migros.ch/assets/mgb-favicons/icon-512x512.png">
# 		<meta property="og:image:alt">
# 		<!-- social:twitter-->
# 		<meta name="twitter:card" content="summary">
# 		<meta name="twitter:title">
# 		<meta name="twitter:image">
# 		<meta name="twitter:image:alt">
# 		<meta name="twitter:description">
# 		<meta property="twitter:image:alt">
# 		<!-- others -->
# 		<meta name="robots" content="index,follow">
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 		<meta name="google-site-verification" content="AcpH2OWFMmq1-72oiAVmQRxD-BI_ITUgRJfzqxRUOUg">
# 		<meta name="fragment" content="!">
# 		<meta name="application-name" content="migros.ch">
# 		<meta name="msapplication-TileColor" content="#e0e0e0">
# 		<meta name="theme-color" content="#ff6600">
# 		<!-- link -->
# 		<link rel="canonical">
# 		<link rel="apple-touch-icon-precomposed" href="/assets/mgb-favicons/apple-touch-icon-precomposed.png?v=2">
# 		<link rel="apple-touch-icon" sizes="180x180" href="/assets/mgb-favicons/apple-touch-icon.png?v=2">
# 		<link rel="icon" type="image/png" sizes="32x32" href="/assets/mgb-favicons/favicon-32x32.png">
# 		<link rel="icon" type="image/png" sizes="16x16" href="/assets/mgb-favicons/favicon-16x16.png">
# 		<link rel="icon" href="/favicon.ico">
# 		<link rel="manifest" href="/manifest.json">
# 		<link rel="mask-icon" sizes="any" href="/assets/mgb-favicons/safari-pinned-tab.svg" color="#ff6600">
#
# 		<link rel="dns-prefetch" href="//www-leshop-ch-cld-res.cloudinary.com">
# 		<link rel="dns-prefetch" href="//res.cloudinary.com">
#
# 		<link rel="preload" href="https://cdn.fonts.net/t/1.css?apiType=css&amp;projectid=8589c36f-af6d-49fb-a731-b3f72d05c1ab" as="style">
# 		<link rel="preload" type="application/json" href="/version.json" as="fetch" crossorigin="">
#
# 		<link rel="preload" type="font/woff2" as="font" href="/assets/fonts/HelveticaNowTextRegular_normal_normal.woff2" crossorigin="">
#
# 		<link rel="preload" type="font/woff2" as="font" href="/assets/fonts/HelveticaNowDisplayBlack_normal_normal.woff2" crossorigin="">
#
# 		<link rel="preload" type="font/woff2" as="font" href="/assets/fonts/HelveticaNowTextBold_normal_normal.woff2" crossorigin="">
#
# 		<link rel="preload" type="font/woff2" as="font" href="/assets/fonts/HelveticaNowDisplayBold_normal_normal.woff2" crossorigin="">
#
# 		<base href="/">
# 		<style type="text/css">
# 			@font-face {
# 				font-family: 'text';
# 				src: url('/assets/fonts/HelveticaNowTextRegular_normal_normal.woff2') format('woff2'),
# 					url('/assets/fonts/HelveticaNowTextRegular_normal_normal.woff') format('woff');
# 				font-weight: 400;
# 				font-stretch: normal;
# 				font-style: normal;
# 				font-display: optional;
# 			}
#
# 			@font-face {
# 				font-family: 'text';
# 				src: url('/assets/fonts/HelveticaNowTextBold_normal_normal.woff2') format('woff2'),
# 					url('/assets/fonts/HelveticaNowTextBold_normal_normal.woff') format('woff');
# 				font-weight: 700;
# 				font-stretch: normal;
# 				font-style: normal;
# 				font-display: optional;
# 			}
#
# 			@font-face {
# 				font-family: 'display';
# 				src: url('/assets/fonts/HelveticaNowDisplayBold_normal_normal.woff2') format('woff2'),
# 					url('/assets/fonts/HelveticaNowDisplayBold_normal_normal.woff') format('woff');
# 				font-weight: 700;
# 				font-stretch: normal;
# 				font-style: normal;
# 				font-display: optional;
# 			}
#
# 			@font-face {
# 				font-family: 'display';
# 				src: url('/assets/fonts/HelveticaNowDisplayBlack_normal_normal.woff2') format('woff2'),
# 					url('/assets/fonts/HelveticaNowDisplayBlack_normal_normal.woff') format('woff');
# 				font-weight: 900;
# 				font-stretch: normal;
# 				font-style: normal;
# 				font-display: optional;
# 			}
#
# 			html,
# 			body {
# 				margin: 0;
# 				padding: 0;
# 				background-color: #fff;
# 			}
#
# 			html,
# 			body,
# 			#application,
# 			#leshopApp,
# 			#splash {
# 				height: 100%;
# 				overflow: hidden;
# 			}
#
# 			body > noscript {
# 				position: absolute;
# 				bottom: 0;
# 				z-index: 13000;
# 				display: block;
# 				padding: 1em 2em;
# 				background-color: #fff;
# 			}
#
# 			#splash {
# 				position: absolute;
# 				top: 0;
# 				left: 0;
# 				right: 0;
# 				bottom: 0;
# 				z-index: 10000;
# 				background-repeat: no-repeat;
# 				background-size: 80px;
# 				background-position: center center;
# 				background-image: url('data:image/svg+xml;base64,...');
# 			}
#
# 			.ls-modal:not(.ls-modal-show) {
# 				visibility: hidden;
# 			}
# 		</style>
# 		<link href="https://cdn.fonts.net/t/1.css?apiType=css&amp;projectid=8589c36f-af6d-49fb-a731-b3f72d05c1ab" rel="stylesheet">
# 		<script src="/browser-check.70c197d81133b1e99ee1.bundle.js"></script>
# 	<style>@charset "UTF-8";app-root{display:block}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextRegular_normal_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextRegular_normal_normal.woff) format("woff");font-weight:400;font-stretch:normal;font-style:normal;font-display:swap}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextItalic_italic_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextItalic_italic_normal.woff) format("woff");font-weight:400;font-stretch:normal;font-style:italic;font-display:swap}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextMedium_normal_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextMedium_normal_normal.woff) format("woff");font-weight:500;font-stretch:normal;font-style:normal;font-display:swap}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextMediumItalic_italic_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextMediumItalic_italic_normal.woff) format("woff");font-weight:500;font-stretch:normal;font-style:italic;font-display:swap}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextBold_normal_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextBold_normal_normal.woff) format("woff");font-weight:700;font-stretch:normal;font-style:normal;font-display:swap}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextBoldItalic_italic_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextBoldItalic_italic_normal.woff) format("woff");font-weight:700;font-stretch:normal;font-style:italic;font-display:swap}html{line-height:1.15;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}a{background-color:transparent;-webkit-text-decoration-skip:objects}*,*:before,*:after{box-sizing:border-box}html{font-size:100%;line-height:1.225;font-family:text,Helvetica,Arial,sans-serif;background-color:#e0e0e0}@media (max-width: 767px){html{position:fixed;width:100%;top:-.0625rem;margin-top:.0625rem}}@media (prefers-color-scheme: dark){html{background-color:#595959}}body{touch-action:manipulation}:root{--mdc-plain-tooltip-supporting-text-font:$base-font-family;--mdc-linear-progress-active-indicator-color:#404040;--mdc-linear-progress-track-height:.5rem;--mdc-circular-progress-active-indicator-color:#ff6600}:root{--swiper-theme-color:#007aff}@media print{@page{size:A4;margin:10mm}html{font-size:9pt!important;padding:0!important;background:white!important}html,app-root,body{position:static!important;height:auto!important}}@media print{html,body,#application{overflow:visible!important}}:root{--top-padding:min(max(max(24px, 1.5rem), 4.5045045045%), max(40px, 2.5rem));--favorite-ratio:2.2;--mobile-side-pad:.5rem;--mobile-side-pad-neg:-.5rem;--desktop-side-pad:0;--header-top-menu-height:0}@media (min-width: 375px){:root{--mobile-side-pad:1rem;--mobile-side-pad-neg:-1rem}}@media (min-width: 768px){:root{--mobile-side-pad:0;--mobile-side-pad-neg:0;--desktop-side-pad:calc((100vw - 120em)/2);--header-top-menu-height:10.9375rem}}@media (min-width: 1359px){:root{--header-top-menu-height:6.25rem}}@media (min-width: 2048px){:root{--favorite-ratio:2}}@media (min-width: 2560px){:root{--favorite-ratio:1.9}}@media (min-width: 2560px) and (min-height: 1200px){:root{--favorite-ratio:1.5}}@media (min-width: 3440px) and (min-height: 1200px){:root{--favorite-ratio:1.6}}@media (min-width: 3440px) and (min-height: 2048px){:root{--favorite-ratio:1.25}}#remStick{position:absolute;z-index:-1;top:0;left:0;width:10rem}@media (min-width: 768px){html{font-size:min(max(12.8px,.8333333333vw),max(12.8px,100vh / (1920 / var(--favorite-ratio)) * 16));padding:0 calc((100vw - 120em)/2)}}</style><link rel="stylesheet" href="styles.d873998bc4a45bb8.css" media="all" onload="this.media='all'"><noscript><link rel="stylesheet" href="styles.d873998bc4a45bb8.css"></noscript><style type="text/css"></style></head>
# 	<body>
# 		<noscript>
# 			<p>
# 				Um den vollen Funktionsumfang dieser Webseite zu erfahren, benötigen Sie JavaScript. Eine Anleitung wie
# 				Sie JavaScript in Ihrem Browser einschalten, befindet sich
# 				<a href="http://www.enable-javascript.com/de/" target="_blank" rel="noopener noreferrer">hier</a>.
# 			</p>
# 			<p>
# 				Pour accéder à toutes les fonctionnalités de ce site, vous devez activer JavaScript. Voici les
# 				<a href="http://www.enable-javascript.com/fr/" target="_blank" rel="noopener noreferrer">
# 					instructions pour activer JavaScript dans votre navigateur Web</a>.
# 			</p>
# 			<p>
# 				For full functionality of this site it is necessary to enable JavaScript. Here are the
# 				<a href="http://www.enable-javascript.com/" target="_blank" rel="noopener noreferrer">
# 					instructions how to enable JavaScript in your web browser</a>.
# 			</p>
# 		</noscript>
# 		<div id="remStick"></div>
# 		<app-root id="application">
# 			<div id="splash"></div>
# 		</app-root>
# 	<script src="runtime.a121467886609cc8.js" type="module"></script><script src="polyfills.c7e9bcc60f52e02e.js" type="module"></script><script src="vendor.33a25e75312bf3a0.js" type="module"></script><script src="main.5fe1be84c0b80d1e.js" type="module"></script>
#
# <div class="cdk-live-announcer-element cdk-visually-hidden" aria-atomic="true" aria-live="polite" id="cdk-live-announcer-0"></div></body></html>

# %%
def fetch_page(ingredients,subing):
    # Informational print
    page = 0
    print(f"Scraping page {page + 1}")
    headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:115.0.1) Gecko/20100101 Firefox/115.0.1'
}
    # Create the response using a header for the language
    response = requests.get(
        f'https://www.migros.ch/en/category/{ingredients}/{subing}',
        headers=headers)
    
    # Create the soup
    soup = BeautifulSoup(response.content, "html.parser")
    
    return soup

# %%
ingredients = ['snacks-sweets']
subing = ['snacks-crisps']

# %%
fetch_page(ingredients,subing)
# Out:
# Scraping page 1
# <!DOCTYPE html>
#
# <html class="no-js" data-critters-container="">
# <head itemscope="" itemtype="http://schema.org/WebSite">
# <script>
# 			if (typeof window !== 'undefined') {
# 				window.prerenderReady = false;
# 			}
# 		</script>
# <meta charset="utf-8"/>
# <title>Migros</title>
# <meta content="Commandez en ligne et gagnez du temps - nous vous livrons vos courses à votre porte. 12'500 produits Migros à prix Migros et articles de marque" name="description"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="migros.ch" itemprop="name" name="apple-mobile-web-app-title"/>
# <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
# <!-- microdata -->
# <meta content="https://www.migros.ch" itemprop="url"/>
# <meta content="Migros" itemprop="description"/>
# <meta content="https://www.migros.ch/assets/mgb-favicons/icon-512x512.png" itemprop="image"/>
# <!-- seo -->
# <meta name="keywords"/>
# <meta name="title"/>
# <!-- social:og-->
# <meta property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="Migros" property="og:site_name"/>
# <meta property="og:title"/>
# <meta property="og:description"/>
# <meta property="og:locale"/>
# <meta content="https://www.migros.ch/assets/mgb-favicons/icon-512x512.png" property="og:image"/>
# <meta property="og:image:alt"/>
# <!-- social:twitter-->
# <meta content="summary" name="twitter:card"/>
# <meta name="twitter:title"/>
# <meta name="twitter:image"/>
# <meta name="twitter:image:alt"/>
# <meta name="twitter:description"/>
# <meta property="twitter:image:alt"/>
# <!-- others -->
# <meta content="index,follow" name="robots"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="AcpH2OWFMmq1-72oiAVmQRxD-BI_ITUgRJfzqxRUOUg" name="google-site-verification"/>
# <meta content="!" name="fragment"/>
# <meta content="migros.ch" name="application-name"/>
# <meta content="#e0e0e0" name="msapplication-TileColor"/>
# <meta content="#ff6600" name="theme-color"/>
# <!-- link -->
# <link rel="canonical"/>
# <link href="/assets/mgb-favicons/apple-touch-icon-precomposed.png?v=2" rel="apple-touch-icon-precomposed"/>
# <link href="/assets/mgb-favicons/apple-touch-icon.png?v=2" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/assets/mgb-favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/assets/mgb-favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/favicon.ico" rel="icon"/>
# <link href="/manifest.json" rel="manifest"/>
# <link color="#ff6600" href="/assets/mgb-favicons/safari-pinned-tab.svg" rel="mask-icon" sizes="any"/>
# <link href="//www-leshop-ch-cld-res.cloudinary.com" rel="dns-prefetch"/>
# <link href="//res.cloudinary.com" rel="dns-prefetch"/>
# <link as="style" href="https://cdn.fonts.net/t/1.css?apiType=css&amp;projectid=8589c36f-af6d-49fb-a731-b3f72d05c1ab" rel="preload"/>
# <link as="fetch" crossorigin="" href="/version.json" rel="preload" type="application/json"/>
# <link as="font" crossorigin="" href="/assets/fonts/HelveticaNowTextRegular_normal_normal.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/fonts/HelveticaNowDisplayBlack_normal_normal.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/fonts/HelveticaNowTextBold_normal_normal.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/fonts/HelveticaNowDisplayBold_normal_normal.woff2" rel="preload" type="font/woff2"/>
# <base href="/"/>
# <style type="text/css">
# 			@font-face {
# 				font-family: 'text';
# 				src: url('/assets/fonts/HelveticaNowTextRegular_normal_normal.woff2') format('woff2'),
# 					url('/assets/fonts/HelveticaNowTextRegular_normal_normal.woff') format('woff');
# 				font-weight: 400;
# 				font-stretch: normal;
# 				font-style: normal;
# 				font-display: optional;
# 			}
#
# 			@font-face {
# 				font-family: 'text';
# 				src: url('/assets/fonts/HelveticaNowTextBold_normal_normal.woff2') format('woff2'),
# 					url('/assets/fonts/HelveticaNowTextBold_normal_normal.woff') format('woff');
# 				font-weight: 700;
# 				font-stretch: normal;
# 				font-style: normal;
# 				font-display: optional;
# 			}
#
# 			@font-face {
# 				font-family: 'display';
# 				src: url('/assets/fonts/HelveticaNowDisplayBold_normal_normal.woff2') format('woff2'),
# 					url('/assets/fonts/HelveticaNowDisplayBold_normal_normal.woff') format('woff');
# 				font-weight: 700;
# 				font-stretch: normal;
# 				font-style: normal;
# 				font-display: optional;
# 			}
#
# 			@font-face {
# 				font-family: 'display';
# 				src: url('/assets/fonts/HelveticaNowDisplayBlack_normal_normal.woff2') format('woff2'),
# 					url('/assets/fonts/HelveticaNowDisplayBlack_normal_normal.woff') format('woff');
# 				font-weight: 900;
# 				font-stretch: normal;
# 				font-style: normal;
# 				font-display: optional;
# 			}
#
# 			html,
# 			body {
# 				margin: 0;
# 				padding: 0;
# 				background-color: #fff;
# 			}
#
# 			html,
# 			body,
# 			#application,
# 			#leshopApp,
# 			#splash {
# 				height: 100%;
# 				overflow: hidden;
# 			}
#
# 			body > noscript {
# 				position: absolute;
# 				bottom: 0;
# 				z-index: 13000;
# 				display: block;
# 				padding: 1em 2em;
# 				background-color: #fff;
# 			}
#
# 			#splash {
# 				position: absolute;
# 				top: 0;
# 				left: 0;
# 				right: 0;
# 				bottom: 0;
# 				z-index: 10000;
# 				background-repeat: no-repeat;
# 				background-size: 80px;
# 				background-position: center center;
# 				background-image: url('data:image/svg+xml;base64,...');
# 			}
#
# 			.ls-modal:not(.ls-modal-show) {
# 				visibility: hidden;
# 			}
# 		</style>
# <link href="https://cdn.fonts.net/t/1.css?apiType=css&amp;projectid=8589c36f-af6d-49fb-a731-b3f72d05c1ab" rel="stylesheet"/>
# <script src="/browser-check.70c197d81133b1e99ee1.bundle.js"></script>
# <style>@charset "UTF-8";app-root{display:block}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextRegular_normal_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextRegular_normal_normal.woff) format("woff");font-weight:400;font-stretch:normal;font-style:normal;font-display:swap}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextItalic_italic_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextItalic_italic_normal.woff) format("woff");font-weight:400;font-stretch:normal;font-style:italic;font-display:swap}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextMedium_normal_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextMedium_normal_normal.woff) format("woff");font-weight:500;font-stretch:normal;font-style:normal;font-display:swap}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextMediumItalic_italic_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextMediumItalic_italic_normal.woff) format("woff");font-weight:500;font-stretch:normal;font-style:italic;font-display:swap}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextBold_normal_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextBold_normal_normal.woff) format("woff");font-weight:700;font-stretch:normal;font-style:normal;font-display:swap}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextBoldItalic_italic_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextBoldItalic_italic_normal.woff) format("woff");font-weight:700;font-stretch:normal;font-style:italic;font-display:swap}html{line-height:1.15;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}a{background-color:transparent;-webkit-text-decoration-skip:objects}*,*:before,*:after{box-sizing:border-box}html{font-size:100%;line-height:1.225;font-family:text,Helvetica,Arial,sans-serif;background-color:#e0e0e0}@media (max-width: 767px){html{position:fixed;width:100%;top:-.0625rem;margin-top:.0625rem}}@media (prefers-color-scheme: dark){html{background-color:#595959}}body{touch-action:manipulation}:root{--mdc-plain-tooltip-supporting-text-font:$base-font-family;--mdc-linear-progress-active-indicator-color:#404040;--mdc-linear-progress-track-height:.5rem;--mdc-circular-progress-active-indicator-color:#ff6600}:root{--swiper-theme-color:#007aff}@media print{@page{size:A4;margin:10mm}html{font-size:9pt!important;padding:0!important;background:white!important}html,app-root,body{position:static!important;height:auto!important}}@media print{html,body,#application{overflow:visible!important}}:root{--top-padding:min(max(max(24px, 1.5rem), 4.5045045045%), max(40px, 2.5rem));--favorite-ratio:2.2;--mobile-side-pad:.5rem;--mobile-side-pad-neg:-.5rem;--desktop-side-pad:0;--header-top-menu-height:0}@media (min-width: 375px){:root{--mobile-side-pad:1rem;--mobile-side-pad-neg:-1rem}}@media (min-width: 768px){:root{--mobile-side-pad:0;--mobile-side-pad-neg:0;--desktop-side-pad:calc((100vw - 120em)/2);--header-top-menu-height:10.9375rem}}@media (min-width: 1359px){:root{--header-top-menu-height:6.25rem}}@media (min-width: 2048px){:root{--favorite-ratio:2}}@media (min-width: 2560px){:root{--favorite-ratio:1.9}}@media (min-width: 2560px) and (min-height: 1200px){:root{--favorite-ratio:1.5}}@media (min-width: 3440px) and (min-height: 1200px){:root{--favorite-ratio:1.6}}@media (min-width: 3440px) and (min-height: 2048px){:root{--favorite-ratio:1.25}}#remStick{position:absolute;z-index:-1;top:0;left:0;width:10rem}@media (min-width: 768px){html{font-size:min(max(12.8px,.8333333333vw),max(12.8px,100vh / (1920 / var(--favorite-ratio)) * 16));padding:0 calc((100vw - 120em)/2)}}</style><link href="styles.d873998bc4a45bb8.css" media="print" onload="this.media='all'" rel="stylesheet"/><noscript><link href="styles.d873998bc4a45bb8.css" rel="stylesheet"/></noscript></head>
# <body>
# <noscript>
# <p>
# 				Um den vollen Funktionsumfang dieser Webseite zu erfahren, benötigen Sie JavaScript. Eine Anleitung wie
# 				Sie JavaScript in Ihrem Browser einschalten, befindet sich
# 				<a href="http://www.enable-javascript.com/de/" rel="noopener noreferrer" target="_blank">hier</a>.
# 			</p>
# <p>
# 				Pour accéder à toutes les fonctionnalités de ce site, vous devez activer JavaScript. Voici les
# 				<a href="http://www.enable-javascript.com/fr/" rel="noopener noreferrer" target="_blank">
# 					instructions pour activer JavaScript dans votre navigateur Web</a>.
# 			</p>
# <p>
# 				For full functionality of this site it is necessary to enable JavaScript. Here are the
# 				<a href="http://www.enable-javascript.com/" rel="noopener noreferrer" target="_blank">
# 					instructions how to enable JavaScript in your web browser</a>.
# 			</p>
# </noscript>
# <div id="remStick"></div>
# <app-root id="application">
# <div id="splash"></div>
# </app-root>
# <script src="runtime.a121467886609cc8.js" type="module"></script><script src="polyfills.c7e9bcc60f52e02e.js" type="module"></script><script src="vendor.33a25e75312bf3a0.js" type="module"></script><script src="main.5fe1be84c0b80d1e.js" type="module"></script></body>
# </html>

# %%
    for book_html in soup.find_all(class_ = "product_pod"):
        # Find the title and price
        dict['Title'].append(book_html.find("h3").find("a").string)
        dict['Price'].append(float(book_html.find(class_ = "price_color").string.strip('£')))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 for book_html in soup.find_all(class_ = "product_pod"):
#       2     # Find the title and price
#       3     dict['Title'].append(book_html.find("h3").find("a").string)
#       4     dict['Price'].append(float(book_html.find(class_ = "price_color").string.strip('£')))
#
# NameError: name 'soup' is not defined

# %%
# Out:
# <html class="no-js" data-critters-container=""><head itemscope="" itemtype="http://schema.org/WebSite">
# 		<script>
# 			if (typeof window !== 'undefined') {
# 				window.prerenderReady = false;
# 			}
# 		</script>
# 		<meta charset="utf-8">
# 		<title>Migros</title>
# 		<meta name="description" content="Commandez en ligne et gagnez du temps - nous vous livrons vos courses à votre porte. 12'500 produits Migros à prix Migros et articles de marque">
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">
# 		<meta name="apple-mobile-web-app-capable" content="yes">
# 		<meta name="apple-mobile-web-app-title" itemprop="name" content="migros.ch">
# 		<meta name="apple-mobile-web-app-status-bar-style" content="default">
# 		<!-- microdata -->
# 		<meta itemprop="url" content="https://www.migros.ch">
# 		<meta itemprop="description" content="Migros">
# 		<meta itemprop="image" content="https://www.migros.ch/assets/mgb-favicons/icon-512x512.png">
# 		<!-- seo -->
# 		<meta name="keywords">
# 		<meta name="title">
# 		<!-- social:og-->
# 		<meta property="og:url">
# 		<meta property="og:type" content="website">
# 		<meta property="og:site_name" content="Migros">
# 		<meta property="og:title">
# 		<meta property="og:description">
# 		<meta property="og:locale">
# 		<meta property="og:image" content="https://www.migros.ch/assets/mgb-favicons/icon-512x512.png">
# 		<meta property="og:image:alt">
# 		<!-- social:twitter-->
# 		<meta name="twitter:card" content="summary">
# 		<meta name="twitter:title">
# 		<meta name="twitter:image">
# 		<meta name="twitter:image:alt">
# 		<meta name="twitter:description">
# 		<meta property="twitter:image:alt">
# 		<!-- others -->
# 		<meta name="robots" content="index,follow">
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 		<meta name="google-site-verification" content="AcpH2OWFMmq1-72oiAVmQRxD-BI_ITUgRJfzqxRUOUg">
# 		<meta name="fragment" content="!">
# 		<meta name="application-name" content="migros.ch">
# 		<meta name="msapplication-TileColor" content="#e0e0e0">
# 		<meta name="theme-color" content="#ff6600">
# 		<!-- link -->
# 		<link rel="canonical">
# 		<link rel="apple-touch-icon-precomposed" href="/assets/mgb-favicons/apple-touch-icon-precomposed.png?v=2">
# 		<link rel="apple-touch-icon" sizes="180x180" href="/assets/mgb-favicons/apple-touch-icon.png?v=2">
# 		<link rel="icon" type="image/png" sizes="32x32" href="/assets/mgb-favicons/favicon-32x32.png">
# 		<link rel="icon" type="image/png" sizes="16x16" href="/assets/mgb-favicons/favicon-16x16.png">
# 		<link rel="icon" href="/favicon.ico">
# 		<link rel="manifest" href="/manifest.json">
# 		<link rel="mask-icon" sizes="any" href="/assets/mgb-favicons/safari-pinned-tab.svg" color="#ff6600">
#
# 		<link rel="dns-prefetch" href="//www-leshop-ch-cld-res.cloudinary.com">
# 		<link rel="dns-prefetch" href="//res.cloudinary.com">
#
# 		<link rel="preload" href="https://cdn.fonts.net/t/1.css?apiType=css&amp;projectid=8589c36f-af6d-49fb-a731-b3f72d05c1ab" as="style">
# 		<link rel="preload" type="application/json" href="/version.json" as="fetch" crossorigin="">
#
# 		<link rel="preload" type="font/woff2" as="font" href="/assets/fonts/HelveticaNowTextRegular_normal_normal.woff2" crossorigin="">
#
# 		<link rel="preload" type="font/woff2" as="font" href="/assets/fonts/HelveticaNowDisplayBlack_normal_normal.woff2" crossorigin="">
#
# 		<link rel="preload" type="font/woff2" as="font" href="/assets/fonts/HelveticaNowTextBold_normal_normal.woff2" crossorigin="">
#
# 		<link rel="preload" type="font/woff2" as="font" href="/assets/fonts/HelveticaNowDisplayBold_normal_normal.woff2" crossorigin="">
#
# 		<base href="/">
# 		<style type="text/css">
# 			@font-face {
# 				font-family: 'text';
# 				src: url('/assets/fonts/HelveticaNowTextRegular_normal_normal.woff2') format('woff2'),
# 					url('/assets/fonts/HelveticaNowTextRegular_normal_normal.woff') format('woff');
# 				font-weight: 400;
# 				font-stretch: normal;
# 				font-style: normal;
# 				font-display: optional;
# 			}
#
# 			@font-face {
# 				font-family: 'text';
# 				src: url('/assets/fonts/HelveticaNowTextBold_normal_normal.woff2') format('woff2'),
# 					url('/assets/fonts/HelveticaNowTextBold_normal_normal.woff') format('woff');
# 				font-weight: 700;
# 				font-stretch: normal;
# 				font-style: normal;
# 				font-display: optional;
# 			}
#
# 			@font-face {
# 				font-family: 'display';
# 				src: url('/assets/fonts/HelveticaNowDisplayBold_normal_normal.woff2') format('woff2'),
# 					url('/assets/fonts/HelveticaNowDisplayBold_normal_normal.woff') format('woff');
# 				font-weight: 700;
# 				font-stretch: normal;
# 				font-style: normal;
# 				font-display: optional;
# 			}
#
# 			@font-face {
# 				font-family: 'display';
# 				src: url('/assets/fonts/HelveticaNowDisplayBlack_normal_normal.woff2') format('woff2'),
# 					url('/assets/fonts/HelveticaNowDisplayBlack_normal_normal.woff') format('woff');
# 				font-weight: 900;
# 				font-stretch: normal;
# 				font-style: normal;
# 				font-display: optional;
# 			}
#
# 			html,
# 			body {
# 				margin: 0;
# 				padding: 0;
# 				background-color: #fff;
# 			}
#
# 			html,
# 			body,
# 			#application,
# 			#leshopApp,
# 			#splash {
# 				height: 100%;
# 				overflow: hidden;
# 			}
#
# 			body > noscript {
# 				position: absolute;
# 				bottom: 0;
# 				z-index: 13000;
# 				display: block;
# 				padding: 1em 2em;
# 				background-color: #fff;
# 			}
#
# 			#splash {
# 				position: absolute;
# 				top: 0;
# 				left: 0;
# 				right: 0;
# 				bottom: 0;
# 				z-index: 10000;
# 				background-repeat: no-repeat;
# 				background-size: 80px;
# 				background-position: center center;
# 				background-image: url('data:image/svg+xml;base64,...');
# 			}
#
# 			.ls-modal:not(.ls-modal-show) {
# 				visibility: hidden;
# 			}
# 		</style>
# 		<link href="https://cdn.fonts.net/t/1.css?apiType=css&amp;projectid=8589c36f-af6d-49fb-a731-b3f72d05c1ab" rel="stylesheet">
# 		<script src="/browser-check.70c197d81133b1e99ee1.bundle.js"></script>
# 	<style>@charset "UTF-8";app-root{display:block}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextRegular_normal_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextRegular_normal_normal.woff) format("woff");font-weight:400;font-stretch:normal;font-style:normal;font-display:swap}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextItalic_italic_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextItalic_italic_normal.woff) format("woff");font-weight:400;font-stretch:normal;font-style:italic;font-display:swap}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextMedium_normal_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextMedium_normal_normal.woff) format("woff");font-weight:500;font-stretch:normal;font-style:normal;font-display:swap}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextMediumItalic_italic_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextMediumItalic_italic_normal.woff) format("woff");font-weight:500;font-stretch:normal;font-style:italic;font-display:swap}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextBold_normal_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextBold_normal_normal.woff) format("woff");font-weight:700;font-stretch:normal;font-style:normal;font-display:swap}@font-face{font-family:text;src:url(/assets/fonts/HelveticaNowTextBoldItalic_italic_normal.woff2) format("woff2"),url(/assets/fonts/HelveticaNowTextBoldItalic_italic_normal.woff) format("woff");font-weight:700;font-stretch:normal;font-style:italic;font-display:swap}html{line-height:1.15;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}a{background-color:transparent;-webkit-text-decoration-skip:objects}*,*:before,*:after{box-sizing:border-box}html{font-size:100%;line-height:1.225;font-family:text,Helvetica,Arial,sans-serif;background-color:#e0e0e0}@media (max-width: 767px){html{position:fixed;width:100%;top:-.0625rem;margin-top:.0625rem}}@media (prefers-color-scheme: dark){html{background-color:#595959}}body{touch-action:manipulation}:root{--mdc-plain-tooltip-supporting-text-font:$base-font-family;--mdc-linear-progress-active-indicator-color:#404040;--mdc-linear-progress-track-height:.5rem;--mdc-circular-progress-active-indicator-color:#ff6600}:root{--swiper-theme-color:#007aff}@media print{@page{size:A4;margin:10mm}html{font-size:9pt!important;padding:0!important;background:white!important}html,app-root,body{position:static!important;height:auto!important}}@media print{html,body,#application{overflow:visible!important}}:root{--top-padding:min(max(max(24px, 1.5rem), 4.5045045045%), max(40px, 2.5rem));--favorite-ratio:2.2;--mobile-side-pad:.5rem;--mobile-side-pad-neg:-.5rem;--desktop-side-pad:0;--header-top-menu-height:0}@media (min-width: 375px){:root{--mobile-side-pad:1rem;--mobile-side-pad-neg:-1rem}}@media (min-width: 768px){:root{--mobile-side-pad:0;--mobile-side-pad-neg:0;--desktop-side-pad:calc((100vw - 120em)/2);--header-top-menu-height:10.9375rem}}@media (min-width: 1359px){:root{--header-top-menu-height:6.25rem}}@media (min-width: 2048px){:root{--favorite-ratio:2}}@media (min-width: 2560px){:root{--favorite-ratio:1.9}}@media (min-width: 2560px) and (min-height: 1200px){:root{--favorite-ratio:1.5}}@media (min-width: 3440px) and (min-height: 1200px){:root{--favorite-ratio:1.6}}@media (min-width: 3440px) and (min-height: 2048px){:root{--favorite-ratio:1.25}}#remStick{position:absolute;z-index:-1;top:0;left:0;width:10rem}@media (min-width: 768px){html{font-size:min(max(12.8px,.8333333333vw),max(12.8px,100vh / (1920 / var(--favorite-ratio)) * 16));padding:0 calc((100vw - 120em)/2)}}</style><link rel="stylesheet" href="styles.3ebf98e3a94d6231.css" media="all" onload="this.media='all'"><noscript><link rel="stylesheet" href="styles.3ebf98e3a94d6231.css"></noscript></head>
# 	<body>
# 		<noscript>
# 			<p>
# 				Um den vollen Funktionsumfang dieser Webseite zu erfahren, benötigen Sie JavaScript. Eine Anleitung wie
# 				Sie JavaScript in Ihrem Browser einschalten, befindet sich
# 				<a href="http://www.enable-javascript.com/de/" target="_blank" rel="noopener noreferrer">hier</a>.
# 			</p>
# 			<p>
# 				Pour accéder à toutes les fonctionnalités de ce site, vous devez activer JavaScript. Voici les
# 				<a href="http://www.enable-javascript.com/fr/" target="_blank" rel="noopener noreferrer">
# 					instructions pour activer JavaScript dans votre navigateur Web</a>.
# 			</p>
# 			<p>
# 				For full functionality of this site it is necessary to enable JavaScript. Here are the
# 				<a href="http://www.enable-javascript.com/" target="_blank" rel="noopener noreferrer">
# 					instructions how to enable JavaScript in your web browser</a>.
# 			</p>
# 		</noscript>
# 		<div id="remStick"></div>
# 		<app-root id="application">
# 			<div id="splash"></div>
# 		</app-root>
# 	<script src="runtime.1401829965b67ff7.js" type="module"></script><script src="polyfills.c7e9bcc60f52e02e.js" type="module"></script><script src="vendor.33a25e75312bf3a0.js" type="module"></script><script src="main.abaf6ac8fad52170.js" type="module"></script>
#
# <div class="cdk-live-announcer-element cdk-visually-hidden" aria-atomic="true" aria-live="polite" id="cdk-live-announcer-0"></div></body></html>

# %%
import asyncio
from pyppeteer import launch

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
from selenium import webdriver
import time 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
import sys

import requests
from bs4 import BeautifulSoup

import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib

race_day_url='https://www.migros.ch/fr/category/fruits-legumes/fruits'
 
browser = webdriver.Firefox()
browser.get(race_day_url)
wait = WebDriverWait(browser, 30)
bouton_voir_plus = wait.until(EC.element_to_be_clickable((By.XPATH, "/html/body/app-root/div[1]/lsp-shop/div/div/div/lsp-supermarket-container/main/div[1]/app-category-level-container/app-category-level2/div/div/app-products-display/div[2]/div/button")))
bouton_voir_plus.click()
time.sleep(3)
answer = browser.page_source
browser.close()

# %%
import requests

# Create a session object
session = requests.Session()

# Make a GET request using the session
response = session.get('https://www.migros.ch/fr/category/fruits-legumes/fruits')

# Access and print the cookies received in the response
cookies = response.cookies
print(cookies)

# You can also add custom cookies to the session
# For example, if you have a cookie named 'session_id':
session.cookies['session_id'] = 'your_session_id_value'

# Now you can make subsequent requests using the session, and it will automatically include the cookies
response2 = session.get('https://www.migros.ch/fr/category/fruits-legumes/legumes')

# To clear cookies from the session, you can use the `clear` method:
session.cookies.clear()
# Out:
# <RequestsCookieJar[]>

# %%
response2.text
# Out:
# '<!DOCTYPE html>\n<html class="no-js" data-critters-container>\n\t<head itemscope itemtype="http://schema.org/WebSite">\n\t\t<script>\n\t\t\tif (typeof window !== \'undefined\') {\n\t\t\t\twindow.prerenderReady = false;\n\t\t\t}\n\t\t</script>\n\t\t<meta charset="utf-8">\n\t\t<title>Migros</title>\n\t\t<meta name="description" content="Commandez en ligne et gagnez du temps - nous vous livrons vos courses Ã\xa0 votre porte. 12\'500 produits Migros Ã\xa0 prix Migros et articles de marque">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">\n\t\t<meta name="apple-mobile-web-app-capable" content="yes">\n\t\t<meta name="apple-mobile-web-app-title" itemprop="name" content="migros.ch">\n\t\t<meta name="apple-mobile-web-app-status-bar-style" content="default">\n\t\t<!-- microdata -->\n\t\t<meta itemprop="url" content="https://www.migros.ch">\n\t\t<meta itemprop="description" content="Migros">\n\t\t<meta itemprop="image" content="https://www.migros.ch/assets/mgb-favicons/icon-512x512.png">\n\t\t<!-- seo -->\n\t\t<meta name="keywords">\n\t\t<meta name="title">\n\t\t<!-- social:og-->\n\t\t<meta property="og:url">\n\t\t<meta property="og:type" content="website">\n\t\t<meta property="og:site_name" content="Migros">\n\t\t<meta property="og:title">\n\t\t<meta property="og:description">\n\t\t<meta property="og:locale">\n\t\t<meta property="og:image" content="https://www.migros.ch/assets/mgb-favicons/icon-512x512.png">\n\t\t<meta property="og:image:alt">\n\t\t<!-- social:twitter-->\n\t\t<meta name="twitter:card" content="summary">\n\t\t<meta name="twitter:title">\n\t\t<meta name="twitter:image">\n\t\t<meta name="twitter:image:alt">\n\t\t<meta name="twitter:description">\n\t\t<meta property="twitter:image:alt">\n\t\t<!-- others -->\n\t\t<meta name="robots" content="index,follow">\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t\t<meta name="google-site-verification" content="AcpH2OWFMmq1-72oiAVmQRxD-BI_ITUgRJfzqxRUOUg">\n\t\t<meta name="fragment" content="!">\n\t\t<meta name="application-name" content="migros.ch">\n\t\t<meta name="msapplication-TileColor" content="#e0e0e0">\n\t\t<meta name="theme-color" content="#ff6600">\n\t\t<!-- link -->\n\t\t<link rel="canonical">\n\t\t<link rel="apple-touch-icon-precomposed" href="/assets/mgb-favicons/apple-touch-icon-precomposed.png?v=2">\n\t\t<link rel="apple-touch-icon" sizes="180x180" href="/assets/mgb-favicons/apple-touch-icon.png?v=2">\n\t\t<link rel="icon" type="image/png" sizes="32x32" href="/assets/mgb-favicons/favicon-32x32.png">\n\t\t<link rel="icon" type="image/png" sizes="16x16" href="/assets/mgb-favicons/favicon-16x16.png">\n\t\t<link rel="icon" href="/favicon.ico">\n\t\t<link rel="manifest" href="/manifest.json">\n\t\t<link rel="mask-icon" sizes="any" href="/assets/mgb-favicons/safari-pinned-tab.svg" color="#ff6600">\n\n\t\t<link rel="dns-prefetch" href="//www-leshop-ch-cld-res.cloudinary.com">\n\t\t<link rel="dns-prefetch" href="//res.cloudinary.com">\n\n\t\t<link rel="preload" href="https://cdn.fonts.net/t/1.css?apiType=css&projectid=8589c36f-af6d-49fb-a731-b3f72d05c1ab" as="style">\n\t\t<link rel="preload" type="application/json" href="/version.json" as="fetch" crossorigin>\n\n\t\t<link rel="preload" type="font/woff2" as="font" href="/assets/fonts/HelveticaNowTextRegular_normal_normal.woff2" crossorigin>\n\n\t\t<link rel="preload" type="font/woff2" as="font" href="/assets/fonts/HelveticaNowDisplayBlack_normal_normal.woff2" crossorigin>\n\n\t\t<link rel="preload" type="font/woff2" as="font" href="/assets/fonts/HelveticaNowTextBold_normal_normal.woff2" crossorigin>\n\n\t\t<link rel="preload" type="font/woff2" as="font" href="/assets/fonts/HelveticaNowDisplayBold_normal_normal.woff2" crossorigin>\n\n\t\t<base href="/">\n\t\t<style type="text/css">\n\t\t\t@font-face {\n\t\t\t\tfont-family: \'text\';\n\t\t\t\tsrc: url(\'/assets/fonts/HelveticaNowTextRegular_normal_normal.woff2\') format(\'woff2\'),\n\t\t\t\t\turl(\'/assets/fonts/Helveti ...

# %%
answer
# Out:
# '<html class="no-js" data-critters-container="" lang="fr"><head itemscope="" itemtype="http://schema.org/WebSite"><script id="one-trust-script-auto-block" src="https://cdn.cookielaw.org/consent/092ec383-3cbc-4b74-8e1b-d3d1ddc269d0/OtAutoBlock.js"></script><script id="one-trust-script" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" data-document-language="true" type="text/javascript" charset="UTF-8" data-domain-script="092ec383-3cbc-4b74-8e1b-d3d1ddc269d0"></script><script src="https://geolocation.onetrust.com/cookieconsentpub/v1/geo/location" type="text/javascript"></script>\n\t\t<script>\n\t\t\tif (typeof window !== \'undefined\') {\n\t\t\t\twindow.prerenderReady = false;\n\t\t\t}\n\t\t</script>\n\t\t<meta charset="utf-8">\n\t\t<title>Achat produit Fruits • Migros</title>\n\t\t<meta name="description" content="Commandez en ligne et gagnez du temps - nous vous livrons vos courses à votre porte. 12\'500 produits Migros à prix Migros et articles de marque">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">\n\t\t<meta name="apple-mobile-web-app-capable" content="yes">\n\t\t<meta name="apple-mobile-web-app-title" itemprop="name" content="Achat produit Fruits • Migros">\n\t\t<meta name="apple-mobile-web-app-status-bar-style" content="default">\n\t\t<!-- microdata -->\n\t\t<meta itemprop="url" content="https://www.migros.ch">\n\t\t<meta itemprop="description" content="Commandez en ligne et gagnez du temps - nous vous livrons vos courses à votre porte. 12\'500 produits Migros à prix Migros et articles de marque">\n\t\t<meta itemprop="image" content="https://www.migros.ch/assets/mgb-favicons/icon-512x512.png">\n\t\t<!-- seo -->\n\t\t<meta name="keywords">\n\t\t<meta name="title" content="Achat produit Fruits • Migros">\n\t\t<!-- social:og-->\n\t\t<meta property="og:url" content="https://www.migros.ch/fr/category/fruits-legumes/fruits">\n\t\t<meta property="og:type" content="website">\n\t\t<meta property="og:site_name" content="Migros">\n\t\t<meta property="og:title" content="Achat produit Fruits • Migros">\n\t\t<meta property="og:description" content="Commandez en ligne et gagnez du temps - nous vous livrons vos courses à votre porte. 12\'500 produits Migros à prix Migros et articles de marque">\n\t\t<meta property="og:locale" content="fr_CH">\n\t\t<meta property="og:image" content="https://www.migros.ch/assets/mgb-favicons/icon-512x512.png">\n\t\t\n\t\t<!-- social:twitter-->\n\t\t<meta name="twitter:card" content="summary">\n\t\t<meta name="twitter:title" content="Achat produit Fruits • Migros">\n\t\t<meta name="twitter:image" content="https://www.migros.ch/assets/mgb-favicons/icon-512x512.png">\n\t\t<meta name="twitter:image:alt" content="Achat produit Fruits • Migros">\n\t\t<meta name="twitter:description" content="Commandez en ligne et gagnez du temps - nous vous livrons vos courses à votre porte. 12\'500 produits Migros à prix Migros et articles de marque">\n\t\t\n\t\t<!-- others -->\n\t\t<meta name="robots" content="index,follow">\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t\t<meta name="google-site-verification" content="AcpH2OWFMmq1-72oiAVmQRxD-BI_ITUgRJfzqxRUOUg">\n\t\t<meta name="fragment" content="!">\n\t\t<meta name="application-name" content="migros.ch">\n\t\t<meta name="msapplication-TileColor" content="#e0e0e0">\n\t\t<meta name="theme-color" content="#ff6600">\n\t\t<!-- link -->\n\t\t\n\t\t<link rel="apple-touch-icon-precomposed" href="/assets/mgb-favicons/apple-touch-icon-precomposed.png?v=2">\n\t\t<link rel="apple-touch-icon" sizes="180x180" href="/assets/mgb-favicons/apple-touch-icon.png?v=2">\n\t\t<link rel="icon" type="image/png" sizes="32x32" href="/assets/mgb-favicons/favicon-32x32.png">\n\t\t<link rel="icon" type="image/png" sizes="16x16" href="/assets/mgb-favicons/favicon-16x16.png">\n\t\t<link rel="icon" href="/favicon.ico">\n\t\t<link rel="manifest" href="/manifest.json">\n\t\t<link rel="mask-icon" sizes="any" href="/assets/mgb-favic ...

# %%
def get_product_info(answer):
    soup = BeautifulSoup(answer, 'html.parser')

    # Extracting product name
    product_name = soup.select_one('lsp-product-name').text.strip()
    product_version = soup.select_one('span[data-cy="product-versioning-100040509"]').text.strip()
    full_product_name = f"{product_name} {product_version}"

    # Extracting product price
    product_price = soup.select_one('lsp-product-price').text.strip()

    return full_product_name, product_price

# Example usage:
product_name, product_price = get_product_info(answer)
print(f"Product Name: {product_name}")
print(f"Product Price: {product_price}")
# Out:
# Product Name: Myrtilles Charentais
# Product Price: 2.95

# %%
soup = BeautifulSoup(answer, 'html.parser')
product_all = soup.find_all('li')

# %%
product_all
# Out:
# [<li _ngcontent-website-js-c2863090841="" class="ng-star-inserted"><a _ngcontent-website-js-c2863090841="" aria-disabled="false" class="mat-focus-indicator mat-button mat-button-base full-range mui-button mui-button-naked-black" data-cy="full-range-item" href="/fr" mat-button=""><span class="mat-button-wrapper"><span _ngcontent-website-js-c2863090841="">Page d'accueil </span></span><span class="mat-ripple mat-button-ripple" matripple=""></span><span class="mat-button-focus-overlay"></span></
4ef927b8403d1aa05d2700c9358a541f7174d75a/noix-de-coco.jpg 525w, https://image.migros.ch/mo-custom/v-w-700-h-600/4ef927b8403d1aa05d2700c9358a541f7174d75a/noix-de-coco.jpg 700w"/><!-- --><!-- --></mo-product-image-universal><!-- --></a><!-- --><a _ngcontent-website-js-c1889378153="" aria-disabled="false" class="mat-focus-indicator product-show-details mat-button mat-button-base" draggable="false" href="/fr/product/266003113200" mat-button=""><span class="mat-button-wrapper"><lsp-product-badges _ngcontent-website-js-c1889378153="" _nghost-website-js-c2790012066="" class="ng-star-inserted"><!-- --></lsp-product-badges><!-- --><!-- --><mo-product-regional-price _ngcontent-website-js-c1889378153="" _nghost-website-js-c3122689078="" class="ng-star-inserted"><span _ngcontent-website-js-c3122689078="" class="regional-price"> Prix régional
#  </span></mo-product-regional-price><!-- --><!-- --><lsp-product-name _ngcontent-website-js-c1889378153="" _nghost-website-js-c2447666635=""><div _ngcontent-website-js-c2447666635="" class="namedesc"><!-- --><span _ngcontent-website-js-c2447666635="" class="desc ng-star-inserted" id="100000757-description"><span _ngcontent-website-js-c2447666635="" class="ng-star-inserted" data-cy="product-name-100000757">Noix de coco</span><!-- --><!-- --></span><!-- --></div></lsp-product-name><div _ngcontent-website-js-c1889378153="" class="product-qty-price"><lsp-product-quantity _ngcontent-website-js-c1889378153="" _nghost-website-js-c145290989=""><span _ngcontent-website-js-c145290989="" class="weight-priceUnit ng-star-inserted" id="100000757-weight"><!-- -->
#  </span><!-- --></lsp-product-quantity><lsp-product-price-quantity _ngcontent-website-js-c1889378153="" _nghost-website-js-c4287975464=""><!-- --></lsp-product-price-quantity></div><lsp-product-pictos _ngcontent-website-js-c1889378153="" _nghost-website-js-c4202325400=""><div _ngcontent-website-js-c4202325400="" class="grid"><!-- --></div></lsp-product-pictos></span><span class="mat-ripple mat-button-ripple" matripple=""></span><span class="mat-button-focus-overlay"></span></a><div _ngcontent-website-js-c1889378153="" class="toolbar-container"><!-- --></div></div><div _ngcontent-website-js-c1889378153="" class="controls"><!-- --><!-- --></div></div></article><!-- --><!-- --><!-- --></li>]

# %%
def get_product_info(answer):
    soup = BeautifulSoup(answer, 'html.parser')
    product_all = soup.find_all('li')
    preprocess = []
    # Extracting product name
    for element in product_all : 
            
        product_name = element.find('lsp-product-name').text.strip()
        preprocess.append(product_name)
        # Extracting product price
        product_price = element.find('lsp-product-price').text.strip()
        preprocess.append(product_price)
    return preprocess

# Example usage:
preprocess = get_product_info(answer)
print(f"Product Name: {preprocess}")
print(f"Product Price: {product_price}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [64], line 16
#      13     return preprocess
#      15 # Example usage:
# ---> 16 preprocess = get_product_info(answer)
#      17 print(f"Product Name: {preprocess}")
#      18 print(f"Product Price: {product_price}")
#
# Cell In [64], line 8, in get_product_info(answer)
#       5 # Extracting product name
#       6 for element in product_all :
# ----> 8     product_name = element.find('lsp-product-name').text.strip()
#       9     preprocess.append(product_name)
#      10     # Extracting product price
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
all_products
# Out:
# [{'name': 'MelonCharentais Charentais', 'price': '1.95'}]

# %%
def get_product_info(answer):
    soup = BeautifulSoup(answer, 'html.parser')
    product_all = soup.find_all('li')
    preprocess = []
    for element in product_all:
        try:
            # Extracting product name
            product_name = element.find('lsp-product-name').text.strip()
            preprocess.append(product_name)
        except AttributeError:
            preprocess.append("N/A (product name not found)")
        try:
            # Extracting product name
            product_name = element.find('lsp-product-badge').text.strip()
            preprocess.append(product_name)
        except AttributeError:
            preprocess.append("N/A (product name not found)")


        try:
            # Extracting product price
            product_price = element.find('lsp-product-price').text.strip()
            preprocess.append(product_price + " ")
        except AttributeError:
            preprocess.append("N/A (product price not found)")
    return preprocess

# Exemple d'utilisation :
preprocess = get_product_info(answer)
for i in range(0, len(preprocess), 2):
    product_name = preprocess[i]
    product_price = preprocess[i+1]
    print(f"Product Name: {product_name}")
    print(f"Product Price: {product_price}")
    print()
# Out:
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: IP-SUISSEOeufs suisses MÉlevage en plein air
# Product Price: 3.95
#
# Product Name: N/A (product name not found)
# Product Price: N/A (product price not found)
#
# Product Name: IP-SUISSEOeufs suisses MÉlevage en plein air
# Product Price: N/A (product price not found)
#
# Product Name: Le Beurre
# Product Price: 3.95
#
# Product Name: ValfloraCrème Fraîche
# Product Price: 2.80
#
# Product Name: IP-SUISSEOeufs suisses MÉlevage en plein air
# Product Price: 3.75
#
# Product Name: IP-SUISSEOeufs suisse SÉlevage en plein air, cuit & coloré
# Product Price: 3.50
#
# Product Name: Alfredo  ClassicoMozzarellaBoule
# Product Price: 1.65
#
# Product Name: BabybelFromage à pâte mi-dure au lait pasteurisé
# Product Price: N/A (product price not found)
#
# Product Name: Migros BioOeufs suisses MÉlevage en plein air
# Product Price: 5.20
#
# Product Name: Migros BioLait entier3.9% de gras, Past
# Product Price: 1.95
#
# Product Name: Aha!Lait partiellement écrémé1.5% de gras, UHT, sans lactose
# Product Price: 2.10
#
# Product Name: Migros BioLait partiellement écrémé2.5% de gras, Past
# Product Price: 1.95
#
# Product Name: Valflora  IP-SUISSELait partiellement écrémé2.5% de gras, UHT
# Product Price: 9.60
#
# Product Name: Le Gruyère  AOPFromage suisse à pâte dure, gras, au lait cruRâpé
# Product Price: 2.70
#
# Product Name: M-BudgetFromage fraisAux herbes
# Product Price: 1.–
#
# Product Name: Mini SalatsossäSauce à saladeFrançaise
# Product Price: 5.50
#
# Product Name: GalbaniMozzarella
# Product Price: 2.35
#
# Product Name: Le Gruyère  AOPFromage suisse à pâte dure, gras, au lait cruRâpé
# Product Price: 4.20
#
# Product Name: M-ClassicCottage CheeseNature
# Product Price: 1.80
#
# Product Name: Valflora  IP-SUISSEDemi-crèmeUHT, 25% de gras
# Product Price: 1.55
#
# Product Name: M-BudgetBeurre de cuisine
# Product Price: 3.30
#
# Product Name: Emmi  LuzernerFromage à la crème lucernois
# Product Price: 3.–
#
# Product Name: Migros BioFeta
# Product Price: 3.20
#
# Product Name: M-BudgetMozzarellaBarre
# Product Price: 2.30
#
# Product Name: Le Gruyère  AOPFromage suisse à pâte dure, gras, au lait cruDoux
# Product Price: 1.90
#
# Product Name: AlnaturaBoisson à base d'avoineNon sucrée
# Product Price: 2.10
#
# Product Name: M-BudgetFromage suisse à pâte extra-dur, 3/4 gras, au lait pasteuriséRâpé
# Product Price: 3.15
#
# Product Name: M-BudgetOeufs importés XSÉlevage en plein air
# Product Price: 5.95
#
# Product Name: Da Emilio  Grana PadanoFromage Italien à pâte extra-dure, râpé, 3/4 gras, au lait cruRâpé
# Product Price: 4.50au lieu de 5.60
#
# Product Name: Da Emilio  Grana PadanoFromage Italien à pâte extra-dure, râpé, 3/4 gras, au lait cruRâpé
# Product Price: 2.30au lieu de 2.90
#
# Product Name: FloralpBeurre de choix
# Product Price: 3.60
#
# Product Name: M-BudgetFromage fraisNature
# Product Price: 1.95
#
# Product Name: TilsiterFromage suisse à pâte mi-dure, gras, au lait pasteuriséDoux
# Product Price: 1.20au lieu de 1.45
#
# Product Name: M-ClassicYogourt fermeMocca
# Product Price: 0.55
#
# Product Name: Le Gruyère  AOPFromage suisse à pâte dure, gras, au lait cruSalé
# Product Price: 2.20
#
# Product Name: Valflora  IP-SUISSECrème entièreUHT, 35% de gras
# Product Price: 2.05
#
# Product Name: ValfloraCrème FraîcheAux herbes
# Product Price: N/A (product price not found)
#
# Product Name: Anna's BestGnocchi CapreseAux tomates et à la mozzarella
# Product Price: 7.90
#
# Product Name: Migros BioYogourtNature
# Product Price: 1.45
#
# Product Name: Le Gruyère  AOPFromage suisse à pâte dure, gras, au lait cruSurchoix
# Product Price: 2.30
#
# Product Name: SélectionBurrata
# Product Price: 4.10
#
# Product Name: Emmentaler  ClassicFromage suisse à pâte dure, gras, au lait cruDoux
# Product Price: N/A (product price not found)
#
# Product Name: M-ClassicYogourt fermeChocolat
# Product Price: 0.55
#
# Product Name: GalbaniMozzarellaMini
# Product Price: 3.55
#
# Product Name: M-BudgetSéré maigre
# Product Price: 1.25
#
# Product Name: Philadelphia  OriginalFromage fraisNature
# Product Price: 2.75
#
# Product Name: Valflora  IP-SUISSELait entier3.5% de gras, UHT
# Product Price: 9.60
#
# Product Name: M-BudgetCottage Cheese
# Product Price: 4.10
#
# Product Name: Alfredo  ClassicoMozzarelline
# Product Price: 2.50
#
# Product Name: M-ClassicBeurre de cuisine
# Product Price: 3.80
#
# Product Name: Valflora  IP-SUISSEDemi-crèmeUHT, 25% de gras
# Product Price: 2.70
#
# Product Name: M-BudgetYogourtNature
# Product Price: 0.90
#
# Product Name: KinderTranche au lait
# Product Price: 1.85
#
# Product Name: Aha!Demi-crèmeSans lactose
# Product Price: 2.80
#
# Product Name: Heidi  IP-SUISSELait partiellement écrémé2.5% de gras, Hoch Past
# Product Price: 1.95
#
# Product Name: M-ClassicSéréFramboise
# Product Price: 0.65
#
# Product Name: M-ClassicSéréFraise
# Product Price: 0.65
#
# Product Name: RaccardRacletteNature - 2x10 tranches
# Product Price: 12.20
#
# Product Name: Migros BioLait partiellement écrémé2.5% de gras, UHT
# Product Price: 1.95
#
# Product Name: M-ClassicLait écrémé0.1% de gras, UHT
# Product Price: 1.65
#
# Product Name: GruyèreFromage fondu10 tranches
# Product Price: 3.20
#
# Product Name: M-BudgetMozzarellaBoule
# Product Price: 1.90
#
# Product Name: Oatly!Boisson à l'avoineBarista
# Product Price: 3.45
#
# Product Name: Anna's BestHummusNature
# Product Price: 3.80
#
# Product Name: M-ClassicSéré maigre
# Product Price: 0.90
#
# Product Name: Valflora  IP-SUISSEDemi-crèmeUHT, 25% de gras
# Product Price: 3.30
#
# Product Name: Raccard  TraditionRacletteNature - 10 tranches
# Product Price: 2.55
#
# Product Name: M-BudgetSpätzli aux oeufs
# Product Price: 3.20
#
# Product Name: Migros BioMozzarella
# Product Price: 2.25
#
# Product Name: M-BudgetTortelloniAux épinards et à la ricotta
# Product Price: 2.25
#
# Product Name: YogosYogourt crémeux à la grecqueClassic
# Product Price: 1.10
#
# Product Name: Heidi  IP-SUISSELait entier3.8% de gras, Hoch Past
# Product Price: 1.95
#
# Product Name: AOPEmmentaler & Le Gruyère Fromage suisse à pâte dureRâpé
# Product Price: 2.70
#
# Product Name: M-ClassicGouda12 tranches
# Product Price: 2.60
#
# Product Name: Le Gruyère  AOPFromage suisse à pâte dure, gras, au lait cruDoux
# Product Price: 1.90
#
# Product Name: Le Gruyère  AOPFromage suisse à pâte dure, gras, au lait cruSalé
# Product Price: N/A (product price not found)
#
# Product Name: Migros BioYogourtNature
# Product Price: 0.75
#
# Product Name: Migros BioLait entier3.5% de gras, UHT
# Product Price: 1.95
#
# Product Name: Migros BioBeurre de choix
# Product Price: 4.40
#
# Product Name: M-ClassicMozzarella râpée
# Product Price: 3.50
#
# Product Name: FloralpBeurre de choix
# Product Price: 4.55
#
# Product Name: M-ClassicYogourtVanille
# Product Price: 0.65
#
# Product Name: Tartare  L'OriginalFromage frais français, double crème, à l'ail et aux fines herbes, à base de lait pasteuriséAil et Fines herbes
# Product Price: 3.30
#
# Product Name: Migros BioOeufs suisses LÉlevage en plein air
# Product Price: N/A (product price not found)
#
# Product Name: Alfredo  ClassicoMozzarellaBarre
# Product Price: 2.80
#
# Product Name: M-ClassicSéréAbricot
# Product Price: 0.65
#
# Product Name: ValfloraCrème à café
# Product Price: 2.05
#
# Product Name: YogosYogourt crémeux à la grecqueClassic
# Product Price: 2.45
#
# Product Name: Alvalle  GazpachoSoupe Méditerranéenne de légumes fraisOriginal
# Product Price: 6.95
#
# Product Name: ValfloraCrème entièreUHT, 35% de gras
# Product Price: 3.50
#
# Product Name: V-Love  BioBoisson à base d'avoineBarista
# Product Price: 3.10
#
# Product Name: ValfloraCrème à caféPortions
# Product Price: 1.15
#
# Product Name: M-ClassicYogourtMocca
# Product Price: 1.95
#
# Product Name: Emmi  Yogi DrinkYogourt DrinkFramboise
# Product Price: N/A (product price not found)
#
# Product Name: M-ClassicCottage CheeseNature
# Product Price: 1.20
#
# Product Name: BifidusYogourtNature
# Product Price: 1.60
#
# Product Name: XeniaFeta
# Product Price: 4.75
#
# Product Name: Chavroux  Tendre BûchePréparation au fromage français à pâte molle, à la crème, au lait de chèvre pasteuriséDouce et crémeuse
# Product Price: 4.20
#
# Product Name: Valflora  IP-SUISSELait partiellement écrémé2.5% de gras, UHT
# Product Price: 1.–
#
# Product Name: Taverna  HalloumiFromage à griller
# Product Price: 4.10au lieu de 4.80
#
# Product Name: RaccardRacletteExtra maxi bloc
# Product Price: 1.35

# %% [markdown]
# ## Clear

# %%
from selenium import webdriver
import time 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
import sys

import requests as re
from bs4 import BeautifulSoup

import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib

from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
def make_a_soup(url, item):
    race_day_url= f'{url}/{item}'
    browser = webdriver.Firefox()
    browser.get(race_day_url)
    wait = WebDriverWait(browser, 5)
    while True:
        try:
            bouton_voir_plus = wait.until(EC.element_to_be_clickable((By.XPATH, "/html/body/app-root/div[1]/lsp-shop/div/div/div/lsp-supermarket-container/main/div[1]/app-category-level-container/app-category-level1/div/div/app-products-display/div[2]/div/button")))
            bouton_voir_plus.click()
            time.sleep(3)
        except Exception as e:
            print("Bouton non trouvé ou erreur :", e)
            break
    answer = browser.page_source
    browser.close()
    return answer, item

# %%
produc_list=[]

# %%
answer, item = make_a_soup('https://www.migros.ch/fr/category', 'pates-condiments-conserves')
# Out:
# Bouton non trouvé ou erreur : Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:187:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:505:5
# element.find/</<@chrome://remote/content/marionette/element.sys.mjs:135:16

# %%
soup = BeautifulSoup(answer, 'html.parser')

# %%
soup.find('lsp-product-name').find('span', class_="desc ng-star-inserted").text
# Out:
# "Thon rosé MSCA l'eau"

# %%
span_elements = soup.find_all('span', attrs={'data-cy': True})

data_dict = {}

# Itérer à travers les éléments et stocker les données dans le dictionnaire
for span in span_elements:
    data_cy_value = span['data-cy']
    content = span.get_text()
    data_dict[data_cy_value] = content

# Afficher le dictionnaire
print(data_dict)
# Out:
# {'boolean-filter-icon': '', '100029991-current-price': ' 1.95 ', '100029991-name': 'M-Classic', 'product-name-100029991': 'Thon rosé MSC', 'product-versioning-100029991': "A l'eau", '100005212-current-price': ' 1.50 ', '100005212-name': 'Longobardi', 'product-name-100005212': 'Tomates pelées en  morceaux au jus', '100001249-current-price': ' 2.95 ', '100001249-name': 'Thomy', 'product-name-100001249': 'Mayonnaise à la française', '100005178-current-price': ' 1.25 ', '100005178-name': 'M-Classic', 'product-name-100005178': 'Grains de maïs', '100005037-current-price': ' 6.95 ', '100005037-name': 'Al Fez', 'product-name-100005037': "Taboulé - Salade rafraîchissante avec huile d'olive", '100019928-current-price': ' 1.95 ', '100019928-name': 'M-Classic', 'product-name-100019928': 'Thon Rosé MSC', 'product-versioning-100019928': "À l'huile de soja", '100047719-current-price': ' 0.95 ', '100047719-name': 'M-Budget', 'product-name-100047719': 'Grains de maïs', '100005680-current-price': ' 14.95 ', '100005680-name': 'Monini  Classico', 'product-name-100005680': "Huile d'olive extra vierge", '100016815-current-price': ' 1.50 ', '100016815-name': 'M-Budget', 'product-name-100016815': 'Mayonnaise', '100023542-current-price': ' 1.60 ', '100023542-name': 'Migros Bio', 'product-name-100023542': 'Tomates pelées hachées', '100004985-current-price': ' 4.55 ', '100004985-name': 'Pancho Villa', 'product-name-100004985': 'Tortillas/Wrap de farine de blé souples', '100013556-current-price': ' 0.70 ', '100013556-name': 'M-Budget', 'product-name-100013556': 'Vinaigre de table', '100005270-current-price': ' 5.40 ', '100005270-name': 'M-Classic', 'product-name-100005270': 'Huile de tournesol', '100023883-current-price': ' 3.80 ', '100023883-name': 'Heinz', 'product-name-100023883': 'Ketchup', '100005566-current-price': ' 1.75 ', '100005566-name': 'M-Classic', 'product-name-100005566': 'Cornettes', 'product-versioning-100005566': 'Grandes avec oeufs', '100032983-current-price': ' 6.90 ', '100032983-name': 'M-Budget', 'product-name-100032983': "Huile d'olive", 'product-versioning-100032983': 'Vierge', '100031448-current-price': ' 5.20 ', '100031448-name': 'M-Classic', 'product-name-100031448': 'Huile de colza', '100047565-current-price': ' 1.30 ', '100047565-name': 'Longobardi', 'product-name-100047565': 'Sauce pizza', 'product-versioning-100047565': 'Basilic', '100001219-current-price': ' 2.95 ', '100001219-name': 'Thomy  Thomynaise', 'product-name-100001219': 'Mayonnaise à calories réduites', 'product-versioning-100001219': 'Light', '100005135-current-price': ' 1.90 ', '100005135-name': 'M-Classic', 'product-name-100005135': "Macaronis de l'alpage", 'product-versioning-100005135': 'Avec oeufs', '100005587-current-price': ' 0.95 ', '100005587-name': 'M-Classic', 'product-name-100005587': 'Concentré de tomates', 'product-versioning-100005587': 'Concentré triple', '100023693-current-price': ' 2.60 ', '100023693-name': 'Thai Kitchen', 'product-name-100023693': 'Lait de noix de coco', '100005194-current-price': ' 0.95 ', '100005194-name': 'M-Classic', 'product-name-100005194': 'Champignons de Paris', 'product-versioning-100005194': 'Coupés', '100005278-current-price': ' 1.20 ', '100005278-name': 'M-Classic', 'product-name-100005278': 'Pois chiches', 'product-versioning-100005278': 'Cuits', '100001090-current-price': ' 1.05 ', '100001090-name': 'Jura-Sel', 'product-name-100001090': 'Sel de cuisine', 'product-versioning-100001090': 'Fluoré et iodé', '100006686-current-price': ' 3.60 ', '100006686-name': 'M-Classic', 'product-name-100006686': 'Safran', 'product-versioning-100006686': '4 sachets de 125mg', '100063451-current-price': ' 1.50 ', '100063451-name': "Salsa  all' Italiana", 'product-name-100063451': 'Sauce tomate', 'product-versioning-100063451': 'Napoli', '100036577-current-price': ' 2.30 ', '100036577-name': 'Condy', 'product-name-100036577': 'Concombres aux fines herbes', '100041113-current-price': ' 1.45 ', '100041113-name': 'Alnatura', 'product-n ...

# %%
def get_product_info(answer):
    soup = BeautifulSoup(answer, 'html.parser')
    product_all = soup.find_all('li')
    name_item = []
    price_item = []
    desc_item = []
    discount_item = []
    comment_item = []
    for element in product_all:
        try:
            # Extracting product name
            product_brand = element.find('lsp-product-name').find('div').find('span').text.strip()
            product_desc = soup.find('lsp-product-name').find('span', class_="desc ng-star-inserted").text.strip()
            name_item.append( product_brand )
            desc_item.append( product_desc )
        except AttributeError:
            name_item.append("NaN")
        try:
            # Extracting product discount
            comment_name = element.find('lsp-product-badge').text.strip()
            comment_item.append(comment_name)
        except AttributeError:
            comment_item.append("NaN")

        try:
            # Extracting product price
            product_price = element.find('lsp-product-price').text.strip()
            if len(product_price)>6 : 
                nombres = re.findall(r'\b\d+\.\d+|\d+\.-|\d+\.\b|\d+\b', product_price)
                # Convertissez les nombres en floats si nécessaire
                nombres_tmp = [nombre for nombre in nombres]
                price_item.append(nombres_tmp[1])
                discount_item.append(nombres_tmp[0])
            else :
                price_item.append(product_price)
                discount_item.append('NaN')
        except AttributeError:
            price_item.append("NaN")
            discount_item.append('NaN')
    return name_item, price_item, discount_item, comment_item

# Exemple d'utilisation :
name_item, price_item,discount_item, comment_item = get_product_info(answer)

# %%
def convert_tab(li1 , li2, li3 , li4, item, subitem): 
    tabu = {'brand': li1, 'prix' : li2, 'ristourne' : li3 , 'comment' : li4 , 'classes' : item +" "+ subitem}
    data = pd.DataFrame(tabu)
    return data

# %%
data = convert_tab(name_item, price_item,discount_item, comment_item, item, subitem)

# %% [raw]
# temp = data.dropna()

# %%
data.tail(50)
# Out:
#                                             noms   prix ristourne comment  \
# 1932                               [Flor de Sal]  12.20       NaN     NaN
# 1933                             [Sel des Alpes]   8.50       NaN     NaN
# 1934                            [Salt Selection]   8.50       NaN     NaN
# 1935                            [Salt Selection]   3.50       NaN     NaN
# 1936                              [Sal de Ibiza]   9.50       NaN     NaN
# 1937                             [Sel des Alpes]    1.–       NaN     NaN
# 1938                             [Sel des Alpes]   7.50       NaN     NaN
# 1939                              [Sal de Ibiza]   8.40       NaN     NaN
# 1940                               [Flor de Sal]  12.20       NaN     NaN
# 1941  [[Maldon flocons de sel marin fumé],  ,  ]   6.90       NaN     NaN
# 1942       [[Maldon flocons de sel marin],  ,  ]   7.45       NaN     NaN
# 1943      [[Sel des Alpes jodé et fluoré],  ,  ]   2.30       NaN     NaN
# 1944              [[Marjolaine],  , [Séchée],  ]   0.75       NaN     NaN
# 1945                                [Migros Bio]   3.70       NaN     NaN
# 1946                                [Migros Bio]   5.95       NaN     NaN
# 1947                                [Migros Bio]   3.95       NaN     NaN
# 1948                                  [M-Budget]   1.10       NaN     NaN
# 1949                                 [M-Classic]   1.10       NaN     NaN
# 1950                              [Sal de Ibiza]  16.50       NaN     NaN
# 1951                 [[Graines de Sésame],  ,  ]   2.20       NaN     NaN
# 1952                                 [M-Classic]   1.60       NaN     NaN
# 1953                            [Salt Selection]   8.50       NaN     NaN
# 1954                            [Salt Selection]   8.50       NaN     NaN
# 1955                                [Kala Namak]   3.90       NaN     NaN
# 1956                                [Migros Bio]   3.70       NaN     NaN
# 1957                               [Riso Scotti]   4.20       NaN     NaN
# 1958                               [Riso Scotti]   5.50       NaN     NaN
# 1959  [[Demeter riz grain Long parboiled],  ,  ]   3.60       NaN     NaN
# 1960                                   [La Cuna]   4.25       NaN     NaN
# 1961                                  [M-Budget]   1.50       NaN     NaN
# 1962                               [Riso Scotti]   4.20       NaN     NaN
# 1963              [[Poivre noir],  , [Moulu],  ]   0.40       NaN     NaN
# 1964                              [Sal de Ibiza]   9.50       NaN     NaN
# 1965                               [Kelly Loves]   2.95       NaN     NaN
# 1966                                  [M-Budget]   1.10       NaN     NaN
# 1967                            [Salt Selection]   8.50       NaN     NaN
# 1968                                  [M-Budget]   0.90       NaN     NaN
# 1969                                  [M-Budget]   0.90       NaN     NaN
# 1970                [[Cannelle],  , [Moulue],  ]   0.45       NaN     NaN
# 1971                               [Kelly Loves]   2.95       NaN     NaN
# 1972                               [Kelly Loves]   2.95       NaN     NaN
# 1973              [[Ail séché],  , [Granulé],  ]   0.60       NaN     NaN
# 1974        [[Poivre de Cayenne],  , [Moulu],  ]   0.50       NaN     NaN
# 1975                                  [M-Budget]   2.20       NaN     NaN
# 1976               [[Curry doux],  , [Moulu],  ]   0.55       NaN     NaN
# 1977             [[Paprika doux],  , [Moulu],  ]   0.50       NaN     NaN
# 1978                                 [Sun Queen]   1.20       NaN     NaN
# 1979                                 [Sun Queen]   2.95       NaN     NaN
# 1980                                  [M-Budget]   1.10       NaN     NaN
# 1981                                 [M-Classic]    2.–       NaN     NaN
#
#                                                 classes
# 1932  pates-condiments-conserves pates-riz-semoules-...
# 1933  pates-condiments-conserves pates-riz-semoules-...
# 1934  pates-condiments-conserves pates-riz-semoules-...
# 1935  pates-condiments-conserves pates-riz-semoules-...
# 1936  pates-condiments-conserves pates-riz-semoules-...
# 1937  pates-condiments-conserves pates-riz-semoules-...
# 1938  pates-condiments-conserves pates-riz-semoules-...
# 1939  pates-condiments-conserves pates-riz-semoules-...
# 1940  pates-condiments-conserves pates-riz-semoules-...
# 1941  pates-condiments-conserves pates-riz-semoules-...
# 1942  pates-condiments-conserves pates-riz-semoules-...
# 1943  pates-condiments-conserves pates-riz-semoules-...
# 1944  pates-condiments-conserves pates-riz-semoules-...
# 1945  pates-condiments-conserves pates-riz-semoules-...
# 1946  pates-condiments-conserves pates-riz-semoules-...
# 1947  pates-condiments-conserves pates-riz-semoules-...
# 1948  pates-condiments-conserves pates-riz-semoules-...
# 1949  pates-condiments-conserves pates-riz-semoules-...
# 1950  pates-condiments-conserves pates-riz-semoules-...
# 1951  pates-condiments-conserves pates-riz-semoules-...
# 1952  pates-condiments-conserves pates-riz-semoules-...
# 1953  pates-condiments-conserves pates-riz-semoules-...
# 1954  pates-condiments-conserves pates-riz-semoules-...
# 1955  pates-condiments-conserves pates-riz-semoules-...
# 1956  pates-condiments-conserves pates-riz-semoules-...
# 1957  pates-condiments-conserves pates-riz-semoules-...
# 1958  pates-condiments-conserves pates-riz-semoules-...
# 1959  pates-condiments-conserves pates-riz-semoules-...
# 1960  pates-condiments-conserves pates-riz-semoules-...
# 1961  pates-condiments-conserves pates-riz-semoules-...
# 1962  pates-condiments-conserves pates-riz-semoules-...
# 1963  pates-condiments-conserves pates-riz-semoules-...
# 1964  pates-condiments-conserves pates-riz-semoules-...
# 1965  pates-condiments-conserves pates-riz-semoules-...
# 1966  pates-condiments-conserves pates-riz-semoules-...
# 1967  pates-condiments-conserves pates-riz-semoules-...
# 1968  pates-condiments-conserves pates-riz-semoules-...
# 1969  pates-condiments-conserves pates-riz-semoules-...
# 1970  pates-condiments-conserves pates-riz-semoules-...
# 1971  pates-condiments-conserves pates-riz-semoules-...
# 1972  pates-condiments-conserves pates-riz-semoules-...
# 1973  pates-condiments-conserves pates-riz-semoules-...
# 1974  pates-condiments-conserves pates-riz-semoules-...
# 1975  pates-condiments-conserves pates-riz-semoules-...
# 1976  pates-condiments-conserves pates-riz-semoules-...
# 1977  pates-condiments-conserves pates-riz-semoules-...
# 1978  pates-condiments-conserves pates-riz-semoules-...
# 1979  pates-condiments-conserves pates-riz-semoules-...
# 1980  pates-condiments-conserves pates-riz-semoules-...
# 1981  pates-condiments-conserves pates-riz-semoules-...
